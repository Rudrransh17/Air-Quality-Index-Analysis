# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn import metrics
import math
import json
from math import floor
from sklearn.metrics import r2_score

# %%
dataset = pd.read_csv('/content/AQI_delhi.csv')

# %%
dataset.head()
# Out:
#          Date  Delhi
# 0  2015-01-01  472.0
# 1  2015-01-02  454.0
# 2  2015-01-03  143.0
# 3  2015-01-04  319.0
# 4  2015-01-05  325.0

# %%
aqi_arr = dataset['Delhi'].to_numpy()
print(aqi_arr)
# Out:
# [472. 454. 143. ... 233. 114. 101.]

# %%
lengths=[0.7, 0.3]           
lookback=1                      

print(len(aqi_arr))

aqi_len=len(aqi_arr)
lim=[floor(aqi_len*lengths[0]),
     floor(aqi_len*(lengths[0]+lengths[1]))]

TrainingData=aqi_arr[:lim[0]]
TestData=aqi_arr[lim[0]:lim[1]]

fig, axs = plt.subplots(2)
axs[0].plot(TrainingData)
axs[0].set_title('Training Data')
axs[1].plot(TestData)
axs[1].set_title('Testing Data')

Xtrain,Ytrain=[],[]
Xtest,Ytest=[],[]


Xtraining=TrainingData[:-1]
Ytraining=TrainingData[1:]
for i in range(len(Xtraining)-lookback+1):
  Xtrain.append(Xtraining[i:i+lookback])
  Ytrain.append(Ytraining[i+lookback-1])

Xtesting=TestData[:-1]
Ytesting=TestData[1:]
for i in range(len(Xtesting)-lookback+1):
  Xtest.append(Xtesting[i:i+lookback])
  Ytest.append(Ytesting[i+lookback-1])

Xtrain=np.array(Xtrain)
Ytrain=np.array(Ytrain)
Xtest=np.array(Xtest)
Ytest=np.array(Ytest)
# Out:
# 2009

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc_X_train=sc.fit_transform(Xtrain)
sc_X_test=sc.fit_transform(Xtest)

# %%
from sklearn.ensemble import ExtraTreesRegressor
reg_extratree= ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
reg_extratree.fit(sc_X_train, Ytrain)
# Out:
# ExtraTreesRegressor(random_state=0)

# %%
y_pred_extratree = reg_extratree.predict(sc_X_test)

# %%
X1=np.arange(0,len(Ytest))

# %%
# plot forecasts against actual outcomes
fig, ax = plt.subplots(figsize = (10,7))
ax.plot(Ytest,label = 'y_test')
ax.plot(y_pred_extratree, color='red',label = 'y_pred')
ax.legend()
plt.ylabel('AQI Delhi',fontweight='bold')
plt.xlabel('datapoints',fontweight='bold')
plt.title('Extra Tree',fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Extra Tree')

# %%
from sklearn.metrics import explained_variance_score,mean_absolute_error,mean_squared_error,mean_absolute_percentage_error,median_absolute_error,r2_score

print("R2 Score = ",r2_score(Ytest, y_pred_extratree))
print("Variance Score = ",explained_variance_score(Ytest, y_pred_extratree))
print("\nMean Absolute Error (MAE) = ",mean_absolute_error(Ytest, y_pred_extratree))
print("Mean Squared Error (MSE) = ",mean_squared_error(Ytest, y_pred_extratree))
print("Root Mean Squared Error (RMSE) = ",mean_squared_error(Ytest, y_pred_extratree,squared=False))
print("Mean Absolute Percentage Error (MAPE) = ",mean_absolute_percentage_error(Ytest, y_pred_extratree))
print("Meadian Relative Absolute Error (MRAE) = ",median_absolute_error(Ytest, y_pred_extratree))
# Out:
# R2 Score =  0.6670757427506566
# Variance Score =  0.7722826386923789
#
# Mean Absolute Error (MAE) =  54.09725797006611
# Mean Squared Error (MSE) =  4737.396331828374
# Root Mean Squared Error (RMSE) =  68.82874640605024
# Mean Absolute Percentage Error (MAPE) =  0.32265542413055287
# Meadian Relative Absolute Error (MRAE) =  46.46944444444458

# %%
extra_tree_res=[r2_score(Ytest, y_pred_extratree),
         explained_variance_score(Ytest, y_pred_extratree),
         mean_absolute_error(Ytest, y_pred_extratree),
         mean_absolute_percentage_error(Ytest, y_pred_extratree),
         mean_squared_error(Ytest, y_pred_extratree,squared=False)]
print("extra_tree_res =",extra_tree_res)
# Out:
# extra_tree_res = [0.6670757427506566, 0.7722826386923789, 54.09725797006611, 0.32265542413055287, 68.82874640605024]
